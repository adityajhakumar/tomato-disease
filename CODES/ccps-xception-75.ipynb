# %%
# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score, roc_curve, confusion_matrix, auc
import seaborn as sns
import time
from keras.layers import Flatten, Dense
from keras.models import Model
from keras.applications import Xception
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define all hyperparameters
BATCH_SIZE = 32
IMAGE_SIZE = 224
EPOCHS = 75
CLASS_NAMES = [
    'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 
    'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 
    'Tomato_Spider_mites_Two_spotted_spider_mite', 
    'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 
    'Tomato__Tomato_mosaic_virus', 'Tomato_healthy'
]

# Load dataset
dataset_dir = "/kaggle/input/plantdisease/PlantVillage"

# Create ImageDataGenerator
image_gen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.xception.preprocess_input,
    validation_split=0.2
)

# Load training and validation data
train_gen = image_gen.flow_from_directory(
    dataset_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    classes=CLASS_NAMES
)

val_gen = image_gen.flow_from_directory(
    dataset_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=True,
    classes=CLASS_NAMES
)

# Create and compile the Xception model
def create_model():
    base_model = Xception(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    prediction = Dense(len(CLASS_NAMES), activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=prediction)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create and compile the model
model = create_model()

# Train the model
start_time = time.time()
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    verbose=1
)
end_time = time.time()
training_time = end_time - start_time
print(f"Training Time: {training_time:.2f} seconds")

# Save the model weights
model.save_weights('/kaggle/working/xception_model_weights.weights.h5')

# Plot accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# Evaluate the model
val_steps = val_gen.samples // BATCH_SIZE + (1 if val_gen.samples % BATCH_SIZE != 0 else 0)
scores = model.evaluate(val_gen, steps=val_steps, verbose=1)
val_accuracy = scores[1]

# Get predictions and labels
y_pred = []
y_true = []
y_pred_prob = []

for i in range(val_steps):
    images, labels = next(val_gen)
    y_true.extend(np.argmax(labels, axis=1))  # Ensure labels are in the correct format
    predictions = model.predict(images)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_pred_prob.extend(predictions)

y_pred_prob = np.array(y_pred_prob)

# Compute metrics
cm = confusion_matrix(y_true, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(CLASS_NAMES)):
    fpr[i], tpr[i], _ = roc_curve(np.array(y_true) == i, y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
average_auc = np.mean(list(roc_auc.values()))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Plot ROC curves for each class
for i in range(len(CLASS_NAMES)):
    plt.figure(figsize=(6, 6))
    plt.plot(fpr[i], tpr[i], label=f'ROC curve of class {CLASS_NAMES[i]} (area = {roc_auc[i]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic (ROC) Curve - {CLASS_NAMES[i]}')
    plt.legend(loc='lower right')
    plt.show()

# Display results
print(f"Results for Xception:")
print(f"  Validation Accuracy: {val_accuracy:.4f}")
print(f"  Precision: {precision:.4f}")
print(f"  Recall: {recall:.4f}")
print(f"  F1 Score: {f1:.4f}")
print(f"  Average AUC: {average_auc:.4f}")
print(f"  Training Time: {training_time:.2f} seconds")

# Load test data for prediction
test_gen = image_gen.flow_from_directory(
    dataset_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=1,
    class_mode='categorical',
    shuffle=True,
    classes=CLASS_NAMES
)

# Select 20 images (2 from each class) for prediction
test_images = []
test_labels = []
num_images_per_class = 2
class_counts = {cls: 0 for cls in CLASS_NAMES}
total_selected = 0

while total_selected < 20:
    images, labels = next(test_gen)
    label = np.argmax(labels[0])
    class_name = CLASS_NAMES[label]
    if class_counts[class_name] < num_images_per_class:
        test_images.append(images[0])
        test_labels.append(label)
        class_counts[class_name] += 1
        total_selected += 1

# Predict and display results for the selected images
plt.figure(figsize=(20, 10))
for i, image in enumerate(test_images):
    plt.subplot(4, 5, i + 1)
    plt.imshow(image.astype("uint8"))
    actual_label = CLASS_NAMES[test_labels[i]]
    prediction = model.predict(np.expand_dims(image, axis=0))
    predicted_label = CLASS_NAMES[np.argmax(prediction)]
    plt.title(f"Actual: {actual_label}\nPredicted: {predicted_label}")
    plt.axis('off')
plt.show()
# Out:
# 2024-06-27 04:55:48.161760: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-27 04:55:48.161873: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-27 04:55:48.427626: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 12813 images belonging to 10 classes.
# Found 3198 images belonging to 10 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/75
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/401 ━━━━━━━━━━━━━━━━━━━━ 2:34:42 23s/step - accuracy: 0.1875 - loss: 2.2654
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719464212.125293      86 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1719464212.161935      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.6907 - loss: 2.6079
# W0000 00:00:1719464321.635447      84 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 170s 368ms/step - accuracy: 0.6909 - loss: 2.6062 - val_accuracy: 0.8358 - val_loss: 1.5140
# Epoch 2/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.8965 - loss: 0.7397 - val_accuracy: 0.8114 - val_loss: 2.1768
# Epoch 3/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 139ms/step - accuracy: 0.9192 - loss: 0.5818 - val_accuracy: 0.8640 - val_loss: 1.6392
# Epoch 4/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9522 - loss: 0.3902 - val_accuracy: 0.8546 - val_loss: 1.8796
# Epoch 5/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9548 - loss: 0.3682 - val_accuracy: 0.9078 - val_loss: 1.1794
# Epoch 6/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9647 - loss: 0.2872 - val_accuracy: 0.8787 - val_loss: 1.7778
# Epoch 7/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9704 - loss: 0.2085 - val_accuracy: 0.9018 - val_loss: 1.3255
# Epoch 8/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9707 - loss: 0.2372 - val_accuracy: 0.8899 - val_loss: 1.8569
# Epoch 9/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9662 - loss: 0.3053 - val_accuracy: 0.8868 - val_loss: 1.9821
# Epoch 10/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9768 - loss: 0.2100 - val_accuracy: 0.8899 - val_loss: 2.0704
# Epoch 11/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9702 - loss: 0.2845 - val_accuracy: 0.9056 - val_loss: 1.9499
# Epoch 12/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9780 - loss: 0.2110 - val_accuracy: 0.8946 - val_loss: 2.3767
# Epoch 13/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9867 - loss: 0.0952 - val_accuracy: 0.8949 - val_loss: 1.9974
# Epoch 14/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9808 - loss: 0.1967 - val_accuracy: 0.8755 - val_loss: 2.6862
# Epoch 15/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9701 - loss: 0.3651 - val_accuracy: 0.9009 - val_loss: 2.1192
# Epoch 16/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9904 - loss: 0.1019 - val_accuracy: 0.9143 - val_loss: 1.9883
# Epoch 17/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9885 - loss: 0.1091 - val_accuracy: 0.9028 - val_loss: 2.4020
# Epoch 18/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9862 - loss: 0.1359 - val_accuracy: 0.9018 - val_loss: 2.6722
# Epoch 19/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9841 - loss: 0.1668 - val_accuracy: 0.9103 - val_loss: 2.3998
# Epoch 20/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9801 - loss: 0.2328 - val_accuracy: 0.8965 - val_loss: 2.7045
# Epoch 21/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9820 - loss: 0.2831 - val_accuracy: 0.9068 - val_loss: 2.5312
# Epoch 22/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9889 - loss: 0.1204 - val_accuracy: 0.9090 - val_loss: 2.5635
# Epoch 23/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9861 - loss: 0.1801 - val_accuracy: 0.8962 - val_loss: 3.1226
# Epoch 24/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9883 - loss: 0.1481 - val_accuracy: 0.9121 - val_loss: 2.6730
# Epoch 25/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9882 - loss: 0.1355 - val_accuracy: 0.8796 - val_loss: 4.1033
# Epoch 26/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 83s 142ms/step - accuracy: 0.9891 - loss: 0.1671 - val_accuracy: 0.9003 - val_loss: 3.0411
# Epoch 27/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9899 - loss: 0.1185 - val_accuracy: 0.8881 - val_loss: 3.7795
# Epoch 28/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9884 - loss: 0.1456 - val_accuracy: 0.8946 - val_loss: 4.0019
# Epoch 29/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9874 - loss: 0.1715 - val_accuracy: 0.9068 - val_loss: 3.0912
# Epoch 30/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9919 - loss: 0.1175 - val_accuracy: 0.9018 - val_loss: 3.2032
# Epoch 31/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9954 - loss: 0.0491 - val_accuracy: 0.8846 - val_loss: 4.0463
# Epoch 32/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9911 - loss: 0.1394 - val_accuracy: 0.9081 - val_loss: 3.2462
# Epoch 33/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9915 - loss: 0.1250 - val_accuracy: 0.9137 - val_loss: 3.4383
# Epoch 34/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9932 - loss: 0.1066 - val_accuracy: 0.8996 - val_loss: 3.7439
# Epoch 35/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9938 - loss: 0.0912 - val_accuracy: 0.8984 - val_loss: 3.3687
# Epoch 36/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9894 - loss: 0.1506 - val_accuracy: 0.9090 - val_loss: 3.2758
# Epoch 37/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9941 - loss: 0.0605 - val_accuracy: 0.8812 - val_loss: 4.3998
# Epoch 38/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9909 - loss: 0.1446 - val_accuracy: 0.9090 - val_loss: 3.5678
# Epoch 39/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9943 - loss: 0.0825 - val_accuracy: 0.9143 - val_loss: 3.1774
# Epoch 40/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9972 - loss: 0.0390 - val_accuracy: 0.9071 - val_loss: 3.7891
# Epoch 41/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9891 - loss: 0.1892 - val_accuracy: 0.9040 - val_loss: 4.0039
# Epoch 42/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9943 - loss: 0.0806 - val_accuracy: 0.9131 - val_loss: 3.6134
# Epoch 43/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9941 - loss: 0.0770 - val_accuracy: 0.8990 - val_loss: 3.8831
# Epoch 44/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9918 - loss: 0.1205 - val_accuracy: 0.9059 - val_loss: 3.5955
# Epoch 45/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9958 - loss: 0.0611 - val_accuracy: 0.9090 - val_loss: 3.7323
# Epoch 46/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9951 - loss: 0.0863 - val_accuracy: 0.9090 - val_loss: 3.7068
# Epoch 47/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9925 - loss: 0.1306 - val_accuracy: 0.9034 - val_loss: 4.2434
# Epoch 48/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9932 - loss: 0.0797 - val_accuracy: 0.9131 - val_loss: 3.8445
# Epoch 49/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9948 - loss: 0.1086 - val_accuracy: 0.8996 - val_loss: 4.0892
# Epoch 50/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9954 - loss: 0.0535 - val_accuracy: 0.9062 - val_loss: 4.2002
# Epoch 51/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9981 - loss: 0.0188 - val_accuracy: 0.9181 - val_loss: 3.5264
# Epoch 52/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9982 - loss: 0.0308 - val_accuracy: 0.9156 - val_loss: 3.8078
# Epoch 53/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9968 - loss: 0.0500 - val_accuracy: 0.9012 - val_loss: 5.0019
# Epoch 54/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9938 - loss: 0.1215 - val_accuracy: 0.9056 - val_loss: 4.5003
# Epoch 55/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9926 - loss: 0.1567 - val_accuracy: 0.9143 - val_loss: 4.1260
# Epoch 56/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9963 - loss: 0.0644 - val_accuracy: 0.9131 - val_loss: 4.1481
# Epoch 57/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 82s 142ms/step - accuracy: 0.9979 - loss: 0.0304 - val_accuracy: 0.9034 - val_loss: 4.5799
# Epoch 58/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9939 - loss: 0.1164 - val_accuracy: 0.9062 - val_loss: 4.5722
# Epoch 59/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9922 - loss: 0.1249 - val_accuracy: 0.9118 - val_loss: 4.2000
# Epoch 60/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9985 - loss: 0.0221 - val_accuracy: 0.9031 - val_loss: 4.5916
# Epoch 61/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9952 - loss: 0.0513 - val_accuracy: 0.8852 - val_loss: 6.5918
# Epoch 62/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9932 - loss: 0.1037 - val_accuracy: 0.9087 - val_loss: 4.5279
# Epoch 63/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9971 - loss: 0.0434 - val_accuracy: 0.8977 - val_loss: 5.2363
# Epoch 64/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 83s 142ms/step - accuracy: 0.9944 - loss: 0.1107 - val_accuracy: 0.9009 - val_loss: 4.8589
# Epoch 65/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9955 - loss: 0.0486 - val_accuracy: 0.9065 - val_loss: 4.5515
# Epoch 66/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 83s 141ms/step - accuracy: 0.9966 - loss: 0.0493 - val_accuracy: 0.9162 - val_loss: 4.1471
# Epoch 67/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9972 - loss: 0.0357 - val_accuracy: 0.9131 - val_loss: 4.4255
# Epoch 68/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9961 - loss: 0.0745 - val_accuracy: 0.9074 - val_loss: 4.6723
# Epoch 69/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9974 - loss: 0.0405 - val_accuracy: 0.9040 - val_loss: 5.1596
# Epoch 70/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 66s 164ms/step - accuracy: 0.9939 - loss: 0.1097 - val_accuracy: 0.9012 - val_loss: 5.4075
# Epoch 71/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9959 - loss: 0.0841 - val_accuracy: 0.9118 - val_loss: 4.3522
# Epoch 72/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 82s 142ms/step - accuracy: 0.9990 - loss: 0.0155 - val_accuracy: 0.9043 - val_loss: 5.4120
# Epoch 73/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9982 - loss: 0.0249 - val_accuracy: 0.9109 - val_loss: 4.5864
# Epoch 74/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 141ms/step - accuracy: 0.9963 - loss: 0.0695 - val_accuracy: 0.9159 - val_loss: 4.1383
# Epoch 75/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 57s 140ms/step - accuracy: 0.9992 - loss: 0.0083 - val_accuracy: 0.9143 - val_loss: 4.2579
# Training Time: 4524.72 seconds
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.9155 - loss: 4.2535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Results for Xception:
#   Validation Accuracy: 0.9143
#   Precision: 0.9156
#   Recall: 0.9143
#   F1 Score: 0.9146
#   Average AUC: 0.9880
#   Training Time: 4524.72 seconds
# Found 16011 images belonging to 10 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
