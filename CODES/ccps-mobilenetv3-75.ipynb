# %%
# Install necessary libraries
# !pip install tensorflow_model_optimization

# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.metrics import precision_recall_fscore_support, roc_curve, auc, confusion_matrix
from keras.layers import Flatten, Dense
from keras.models import Model
from keras.applications import MobileNetV3Large
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define all hyperparameters
BATCH_SIZE = 32
IMAGE_SIZE = 224
EPOCHS = 75
CLASS_NAMES = [
    'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 
    'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 
    'Tomato_Spider_mites_Two_spotted_spider_mite', 
    'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 
    'Tomato__Tomato_mosaic_virus', 'Tomato_healthy'
]

# Dataset directory
dataset_directory_location = '/kaggle/input/plantdisease/PlantVillage'

# Create ImageDataGenerator
image_gen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input,
    validation_split=0.2
)

# Load training and validation data
train_gen = image_gen.flow_from_directory(
    dataset_directory_location,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    classes=CLASS_NAMES
)

val_gen = image_gen.flow_from_directory(
    dataset_directory_location,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=True,
    classes=CLASS_NAMES
)

# Create and compile the MobileNetV3 model
def create_model():
    base_model = MobileNetV3Large(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), weights='imagenet', include_top=False)
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    prediction = Dense(len(CLASS_NAMES), activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=prediction)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create and compile the model
model = create_model()

# Train the model
start_time = time.time()
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    verbose=1
)
end_time = time.time()
training_time = end_time - start_time
print(f"Training Time: {training_time:.2f} seconds")

# Save the model weights
model.save_weights('/kaggle/working/mobilenetv3_model_weights.weights.h5')

# Plot accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# Evaluate the model
val_steps = val_gen.samples // BATCH_SIZE + (1 if val_gen.samples % BATCH_SIZE != 0 else 0)
scores = model.evaluate(val_gen, steps=val_steps, verbose=1)
val_accuracy = scores[1]

# Get predictions and labels
y_pred = []
y_true = []
y_pred_prob = []

for i in range(val_steps):
    images, labels = next(val_gen)
    y_true.extend(np.argmax(labels, axis=1))  # Ensure labels are in the correct format
    predictions = model.predict(images)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_pred_prob.extend(predictions)

y_pred_prob = np.array(y_pred_prob)

# Compute metrics
cm = confusion_matrix(y_true, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(CLASS_NAMES)):
    fpr[i], tpr[i], _ = roc_curve(np.array(y_true) == i, y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
average_auc = np.mean(list(roc_auc.values()))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Plot ROC curves for each class
for i in range(len(CLASS_NAMES)):
    plt.figure(figsize=(6, 6))
    plt.plot(fpr[i], tpr[i], label=f'ROC curve of class {CLASS_NAMES[i]} (area = {roc_auc[i]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic (ROC) Curve - {CLASS_NAMES[i]}')
    plt.legend(loc='lower right')
    plt.show()

# Display results
print(f"Results for MobileNetV3:")
print(f"  Validation Accuracy: {val_accuracy:.4f}")
print(f"  Precision: {precision:.4f}")
print(f"  Recall: {recall:.4f}")
print(f"  F1 Score: {f1:.4f}")
print(f"  Average AUC: {average_auc:.4f}")
print(f"  Training Time: {training_time:.2f} seconds")

# Load test data for prediction
test_gen = image_gen.flow_from_directory(
    dataset_directory_location,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=1,
    class_mode='categorical',
    shuffle=True,
    classes=CLASS_NAMES
)

# Select 20 images (2 from each class) for prediction
test_images = []
test_labels = []
num_images_per_class = 2
class_counts = {cls: 0 for cls in CLASS_NAMES}
total_selected = 0

while total_selected < 20:
    images, labels = next(test_gen)
    label = np.argmax(labels[0])
    class_name = CLASS_NAMES[label]
    if class_counts[class_name] < num_images_per_class:
        test_images.append(images[0])
        test_labels.append(label)
        class_counts[class_name] += 1
        total_selected += 1

# Predict and display results for the selected images
plt.figure(figsize=(20, 10))
for i, image in enumerate(test_images):
    plt.subplot(4, 5, i + 1)
    plt.imshow(image.astype("uint8"))
    actual_label = CLASS_NAMES[test_labels[i]]
    prediction = model.predict(np.expand_dims(image, axis=0))
    predicted_label = CLASS_NAMES[np.argmax(prediction)]
    plt.title(f"Actual: {actual_label}\nPredicted: {predicted_label}")
    plt.axis('off')
plt.show()
# Out:
# Collecting tensorflow_model_optimization
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl.metadata (904 bytes)
# Requirement already satisfied: absl-py~=1.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow_model_optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow_model_optimization) (0.1.8)
# Requirement already satisfied: numpy~=1.23 in /opt/conda/lib/python3.10/site-packages (from tensorflow_model_optimization) (1.26.4)
# Requirement already satisfied: six~=1.14 in /opt/conda/lib/python3.10/site-packages (from tensorflow_model_optimization) (1.16.0)
# Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: tensorflow_model_optimization
# Successfully installed tensorflow_model_optimization-0.8.0
# 2024-06-27 03:12:29.487792: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-27 03:12:29.487890: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-27 03:12:29.653612: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 12813 images belonging to 10 classes.
# Found 3198 images belonging to 10 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/75
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/401 ━━━━━━━━━━━━━━━━━━━━ 2:00:14 18s/step - accuracy: 0.0938 - loss: 5.0248
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719458001.067622      90 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1719458001.105542      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 400/401 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7683 - loss: 2.2743
# W0000 00:00:1719458106.398632      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 155s 342ms/step - accuracy: 0.7687 - loss: 2.2693 - val_accuracy: 0.9078 - val_loss: 0.9851
# Epoch 2/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 32s 79ms/step - accuracy: 0.9636 - loss: 0.2636 - val_accuracy: 0.9153 - val_loss: 1.0077
# Epoch 3/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 32s 78ms/step - accuracy: 0.9787 - loss: 0.1862 - val_accuracy: 0.9262 - val_loss: 0.9577
# Epoch 4/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 32s 78ms/step - accuracy: 0.9751 - loss: 0.2232 - val_accuracy: 0.8959 - val_loss: 2.1335
# Epoch 5/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.9851 - loss: 0.1574 - val_accuracy: 0.9400 - val_loss: 0.9474
# Epoch 6/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9883 - loss: 0.1116 - val_accuracy: 0.9350 - val_loss: 1.2268
# Epoch 7/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 75ms/step - accuracy: 0.9885 - loss: 0.1084 - val_accuracy: 0.9468 - val_loss: 1.0400
# Epoch 8/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9897 - loss: 0.1054 - val_accuracy: 0.9331 - val_loss: 1.3681
# Epoch 9/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 75ms/step - accuracy: 0.9882 - loss: 0.1469 - val_accuracy: 0.9406 - val_loss: 1.3619
# Epoch 10/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 75ms/step - accuracy: 0.9876 - loss: 0.1814 - val_accuracy: 0.9087 - val_loss: 2.5814
# Epoch 11/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 0.9915 - loss: 0.0879 - val_accuracy: 0.9412 - val_loss: 1.5540
# Epoch 12/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9940 - loss: 0.0927 - val_accuracy: 0.9478 - val_loss: 1.3347
# Epoch 13/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9961 - loss: 0.0497 - val_accuracy: 0.9462 - val_loss: 1.3858
# Epoch 14/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.9909 - loss: 0.1389 - val_accuracy: 0.9359 - val_loss: 2.0752
# Epoch 15/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9883 - loss: 0.1633 - val_accuracy: 0.9412 - val_loss: 1.8782
# Epoch 16/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 32s 79ms/step - accuracy: 0.9964 - loss: 0.0488 - val_accuracy: 0.9475 - val_loss: 1.6830
# Epoch 17/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 32s 78ms/step - accuracy: 0.9961 - loss: 0.0475 - val_accuracy: 0.9415 - val_loss: 2.1599
# Epoch 18/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 32s 79ms/step - accuracy: 0.9953 - loss: 0.0730 - val_accuracy: 0.9343 - val_loss: 2.3399
# Epoch 19/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 32s 78ms/step - accuracy: 0.9948 - loss: 0.1053 - val_accuracy: 0.9556 - val_loss: 1.5700
# Epoch 20/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9943 - loss: 0.1246 - val_accuracy: 0.9431 - val_loss: 2.1135
# Epoch 21/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9953 - loss: 0.0754 - val_accuracy: 0.9559 - val_loss: 1.6533
# Epoch 22/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.9971 - loss: 0.0504 - val_accuracy: 0.9497 - val_loss: 1.7043
# Epoch 23/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9971 - loss: 0.0600 - val_accuracy: 0.9559 - val_loss: 1.5275
# Epoch 24/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9978 - loss: 0.0378 - val_accuracy: 0.9456 - val_loss: 2.0213
# Epoch 25/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.9966 - loss: 0.0469 - val_accuracy: 0.9493 - val_loss: 2.0042
# Epoch 26/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9971 - loss: 0.0482 - val_accuracy: 0.9531 - val_loss: 1.9073
# Epoch 27/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.9943 - loss: 0.1103 - val_accuracy: 0.9447 - val_loss: 2.0845
# Epoch 28/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9976 - loss: 0.0514 - val_accuracy: 0.9409 - val_loss: 2.6490
# Epoch 29/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9965 - loss: 0.0789 - val_accuracy: 0.9565 - val_loss: 1.9392
# Epoch 30/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 40s 72ms/step - accuracy: 0.9974 - loss: 0.0405 - val_accuracy: 0.9568 - val_loss: 1.9544
# Epoch 31/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.9990 - loss: 0.0129 - val_accuracy: 0.9587 - val_loss: 1.8009
# Epoch 32/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 28s 68ms/step - accuracy: 0.9983 - loss: 0.0266 - val_accuracy: 0.9518 - val_loss: 2.0316
# Epoch 33/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 43s 73ms/step - accuracy: 0.9993 - loss: 0.0125 - val_accuracy: 0.9384 - val_loss: 3.1642
# Epoch 34/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9955 - loss: 0.0853 - val_accuracy: 0.9465 - val_loss: 2.9159
# Epoch 35/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 75ms/step - accuracy: 0.9974 - loss: 0.0609 - val_accuracy: 0.9497 - val_loss: 2.2225
# Epoch 36/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - accuracy: 0.9982 - loss: 0.0347 - val_accuracy: 0.9456 - val_loss: 2.7452
# Epoch 37/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 0.9955 - loss: 0.0990 - val_accuracy: 0.9465 - val_loss: 2.7641
# Epoch 38/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - accuracy: 0.9983 - loss: 0.0185 - val_accuracy: 0.9437 - val_loss: 2.8910
# Epoch 39/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 0.9977 - loss: 0.0545 - val_accuracy: 0.9547 - val_loss: 2.2208
# Epoch 40/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 0.9997 - loss: 0.0081 - val_accuracy: 0.9550 - val_loss: 2.2792
# Epoch 41/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 28s 69ms/step - accuracy: 0.9986 - loss: 0.0320 - val_accuracy: 0.9534 - val_loss: 2.6741
# Epoch 42/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 0.9985 - loss: 0.0307 - val_accuracy: 0.9371 - val_loss: 3.8030
# Epoch 43/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 0.9953 - loss: 0.1325 - val_accuracy: 0.9497 - val_loss: 2.8899
# Epoch 44/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 70ms/step - accuracy: 0.9993 - loss: 0.0148 - val_accuracy: 0.9509 - val_loss: 2.8105
# Epoch 45/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 0.9989 - loss: 0.0118 - val_accuracy: 0.9472 - val_loss: 3.1213
# Epoch 46/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 0.9992 - loss: 0.0057 - val_accuracy: 0.9534 - val_loss: 2.4841
# Epoch 47/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 1.0845e-06 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 48/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 49/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 50/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 51/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 52/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 53/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 54/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 55/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 56/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 57/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 58/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 59/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 60/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 61/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 62/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 63/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 64/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 42s 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 65/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 66/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 67/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 68/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 69/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 70/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 71/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 72/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 73/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 29s 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4591
# Epoch 74/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4590
# Epoch 75/75
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 30s 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9534 - val_loss: 2.4590
# Training Time: 2432.41 seconds
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9545 - loss: 2.2589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Results for MobileNetV3:
#   Validation Accuracy: 0.9534
#   Precision: 0.9534
#   Recall: 0.9534
#   F1 Score: 0.9531
#   Average AUC: 0.9930
#   Training Time: 2432.41 seconds
# Found 16011 images belonging to 10 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
